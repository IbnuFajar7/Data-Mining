# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics

# %%
dataibnu = pd.read_csv("titanic1.csv")
dataibnu.dropna(inplace=True)

# %%
dataibnu.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
dataibnu[['Age', 'Survived']].groupby(['Survived'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Survived        Age
# 1         1  28.408392
# 0         0  30.138532

# %%
dataibnu[['Fare', 'Survived']].groupby(['Survived'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    Survived       Fare
# 1         1  48.395408
# 0         0  22.208584

# %%
pd.crosstab(dataibnu['Sex'], dataibnu['Survived'])
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      464  109

# %%
pd.crosstab(dataibnu['Pclass'], dataibnu['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         368  119

# %%
import seaborn as sns
sns.boxplot(x ='Survived', y ='Age', data = dataibnu)

# %%
sns.boxplot(x ='Survived', y ='Fare', data = dataibnu)
